# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("StateWise_AQI_2019.xlsx")

# %%
df.head()
# Out:
#           States/UTs  AQI Index
# 0     Andhra Pradesh         94
# 1  Arunachal Pradesh         62
# 2              Assam         60
# 3              Bihar        144
# 4       Chhattisgarh        189

# %%
plot.figure(figsize=(200, 16))
df.plot.scatter(x = 'States/UTs', y = 'AQI Index', title = "Scatter plot pandas variable for X and Y axis",c='red',  # Set color of points
                s=50,     # Set size of points
                alpha=0.7) # Set transparency of points);  
plot.show();

# %%
df.columns
# Out:
# Index(['States/UTs', 'AQI Index'], dtype='object')

# %%
stateName = input("Enter the State")
#chhattisgarh_row = df[df["States/UTs"]==text]
# Out:
# Enter the State Punjab

# %%
val= df[df["States/UTs"]==stateName]["AQI Index"].values
print(val[0])
# Out:
# 160

# %%
# Create the scatter plot
plt.figure(figsize=(12, 6))
plt.scatter(df['States/UTs'], df['AQI Index'], color='blue', label='Data Points',alpha=0.7)
plt.xticks(rotation=45, ha='right')

# Find the corresponding Y value for the specified X value
y_highlight = df[df['States/UTs'] == x_highlight]['AQI Index'].values

# Highlight the specific point
if len(y_highlight) > 0:
    plt.scatter(x_highlight, y_highlight[0], color='red', s=300, label=f'Highlighted State (X={stateName})',alpha=0.5)

# Add labels and title
plt.xlabel('States Names')
plt.ylabel('AQI Index')
plt.title(f'Scatter Plot with Highlighted State {stateName} is :{val[0]}')

# Add a legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()
